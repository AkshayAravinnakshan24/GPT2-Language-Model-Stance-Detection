# %%
# !pip install import-ipynb
import import_ipynb,StarStancePredictor
from StarStancePredictor import Star_Stance_Model

tweet='Innovation pioneer @bill_fischer: #climatechange #sustainability #climateemergency #takingastand #takingaction "Far from being partisan, this was an attack on â€œAll those politicians who dont believe we should do anything about climate change." https://t.co/vk7aCOmVwg'
Output=StarStancePredictor.Star_Stance_Model(tweet)
print(str(Output.Stance_)+', '+ str(Output.Probability_Scores_[1])+', '+ str(Output.Probability_Scores_[0])+', '+ str(Output.Probability_Scores_[2]))
# Out:
# Requirement already satisfied: import-ipynb in c:\users\aaravi\anaconda3\envs\star_stance\lib\site-packages (0.1.3)
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/1 [00:00<?, ?it/s]
# <class 'list'>
# FAVOR, 0.9292293587747507, 0.005351526018536176, 0.05933884471104162
